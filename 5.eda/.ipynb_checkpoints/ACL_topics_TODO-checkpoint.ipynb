# %% [markdown]
# In `acl.all.tsv` you'll find 7,188 papers published at major NLP venues (ACL, EMNLP, NAACL, TACL, etc.) between 2013 and 2020.  Your job is to use topic modeling to discover what topics in NLP have been increasing or decreasing in use over this time.  Here is a sample of the data we'll use:
#
# |id|year of publication|title|abstract|
# |---|---|---|---|
# |pimentel-etal-2020-phonotactic|2020|Phonotactic Complexity and Its Trade-offs|We present methods for calculating a measure of phonotactic complexity---bits per phoneme--- that permits a straightforward cross-linguistic comparison. When given a word, represented as a sequence of phonemic segments such as symbols in the international phonetic alphabet, and a statistical model trained on a sample of word types from the language, we can approximately measure bits per phoneme using the negative log-probability of that word under the model. This simple measure allows us to compare the entropy across languages, giving insight into how complex a language's phonotactics is. Using a collection of 1016 basic concept words across 106 languages, we demonstrate a very strong negative correlation of − 0.74 between bits per phoneme and the average length of words.|
# |wang-etal-2020-amr|2020|AMR-To-Text Generation with Graph Transformer|Abstract meaning representation (AMR)-to-text generation is the challenging task of generating natural language texts from AMR graphs, where nodes represent concepts and edges denote relations. The current state-of-the-art methods use graph-to-sequence models; however, they still cannot significantly outperform the previous sequence-to-sequence models or statistical approaches. In this paper, we propose a novel graph-to-sequence model (Graph Transformer) to address this task. The model directly encodes the AMR graphs and learns the node representations. A pairwise interaction function is used for computing the semantic relations between the concepts. Moreover, attention mechanisms are used for aggregating the information from the incoming and outgoing neighbors, which help the model to capture the semantic information effectively. Our model outperforms the state-of-the-art neural approach by 1.5 BLEU points on LDC2015E86 and 4.8 BLEU points on LDC2017T10 and achieves new state-of-the-art performances.|

# %% [markdown]
# First, let's read in the data and train a topic model on it (you are free to set the number of topics $K$ as you see fit.

# %%
#K=50 initial, switching to 10 for easier to view graphs
K=10

# %%
import nltk
import re
import gensim
from gensim import corpora
import operator

nltk.download('stopwords')
from nltk.corpus import stopwords

import numpy as np
import random

random.seed(1)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/castroian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = stopwords.words('english')

# %%
def filter(word, stopwords):
    
    """ Function to exclude words from a text """
    
    # no stopwords
    if word in stopwords:
        return False
    
    # has to contain at least one letter
    if re.search("[A-Za-z]", word) is not None:
        return True
    
    return False

# %%
def read_docs(dataFile, stopwords):
    
    names=[]    
    docs=[]
   
    with open(dataFile, encoding="utf-8") as file:
        for line in file:
            cols=line.rstrip().split("\t")
            idd=cols[0]
            name=cols[2]
            year=int(cols[1])
        
            text=cols[3]
            
            tokens=nltk.word_tokenize(text.lower())
            tokens=[x for x in tokens if filter(x, stopwords)]
            docs.append(tokens)
            names.append((name, year))
    return docs, names

# %%
dataFile="../data/acl.all.tsv"
data, doc_names=read_docs(dataFile, stop_words)

# %% [markdown]
# We will convert the data into a bag-of-words representation using gensim's [corpora.dictionary](https://radimrehurek.com/gensim/corpora/dictionary.html) methods.

# %%
# Create vocab from data; restrict vocab to only the top 10K terms that show up in at least 5 documents 
# and no more than 50% of all documents

dictionary = corpora.Dictionary(data)
dictionary.filter_extremes(no_below=5, no_above=.5, keep_n=10000)

# %%
# Replace dataset with numeric ids words in vocab (and exclude all other words)
corpus = [dictionary.doc2bow(text) for text in data]

# %% [markdown]
# Now let's run a topic model on this data using gensim's built-in LDA.

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=dictionary,
                                           num_topics=K, 
                                           passes=10,
                                           alpha='auto')

# %% [markdown]
# We can get a sense of what the topics are by printing the top 10 words with highest $P(word \mid topic)$ for each topic

# %%
for i in range(K):
    print("topic %s:\t%s" % (i, ' '.join([term for term, freq in lda_model.show_topic(i, topn=10)])))
# Out:
# topic 0:	information question propose neural state-of-the-art network attention datasets results knowledge
# topic 1:	summarization visual image features social human semantic information dataset summaries
# topic 2:	translation models neural machine training nmt show language performance tasks
# topic 3:	word embeddings language languages words models representations tasks embedding learning
# topic 4:	language nlp natural processing research tasks models tutorial linguistic analysis
# topic 5:	generation text evaluation models human method topic propose training show
# topic 6:	knowledge extraction relation relations event models events information task approach
# topic 7:	parsing semantic dependency syntactic parser task features entity system results
# topic 8:	sentiment dialogue learning user task show models dialog propose paper
# topic 9:	data domain dataset corpus text domains training new annotation task

# %% [markdown]
# Now let's print out the documents that have the highest topic representation -- i.e., for a given topic $k$, the documents with highest $P(topic=k | document)$ -- in order to ground these topic summaries with actual documents that contain those topics.

# %%
topic_model=lda_model 

topic_docs=[]
for i in range(K):
    topic_docs.append({})
for doc_id in range(len(corpus)):
    doc_topics=topic_model.get_document_topics(corpus[doc_id])
    for topic_num, topic_prob in doc_topics:
        topic_docs[topic_num][doc_id]=topic_prob

for i in range(K):
    print("%s\n" % ' '.join([term for term, freq in topic_model.show_topic(i, topn=10)]))
    sorted_x = sorted(topic_docs[i].items(), key=operator.itemgetter(1), reverse=True)
    for k, v in sorted_x[:5]:
        print("%s\t%.3f\t%s" % (i,v,doc_names[k]))
    print()
# Out:
# information question propose neural state-of-the-art network attention datasets results knowledge
#
# 0	0.987	('Global-to-Local Neural Networks for Document-Level Relation Extraction', 2020)
# 0	0.986	('Message Passing for Hyper-Relational Knowledge Graphs', 2020)
# 0	0.985	('Double Graph Based Reasoning for Document-level Relation Extraction', 2020)
# 0	0.984	('Disconnected Recurrent Neural Networks for Text Categorization', 2018)
# 0	0.984	('BAG: Bi-directional Attention Entity Graph Convolutional Network for Multi-hop Reasoning Question Answering', 2019)
#
# summarization visual image features social human semantic information dataset summaries
#
# 1	0.893	('An Evaluation of Image-Based Verb Prediction Models against Human Eye-Tracking Data', 2018)
# 1	0.871	('Grounding Action Descriptions in Videos', 2013)
# 1	0.801	('Not All Reviews Are Equal: Towards Addressing Reviewer Biases for Opinion Summarization', 2019)
# 1	0.767	('Facet-Aware Evaluation for Extractive Summarization', 2020)
# 1	0.755	('Improving ROUGE for Timeline Summarization', 2017)
#
# translation models neural machine training nmt show language performance tasks
#
# 2	0.990	('Robust Encodings: A Framework for Combating Adversarial Typos', 2020)
# 2	0.989	('A Stable and Effective Learning Strategy for Trainable Greedy Decoding', 2018)
# 2	0.987	('Pronoun-Targeted Fine-tuning for NMT with Hybrid Losses', 2020)
# 2	0.987	('Towards a Better Understanding of Label Smoothing in Neural Machine Translation', 2020)
# 2	0.984	('Training Neural Machine Translation to Apply Terminology Constraints', 2019)
#
# word embeddings language languages words models representations tasks embedding learning
#
# 3	0.988	('Learning Bilingual Sentiment-Specific Word Embeddings without Cross-lingual Supervision', 2019)
# 3	0.986	('Double-Hard Debias: Tailoring Word Embeddings for Gender Bias Mitigation', 2020)
# 3	0.982	('MultiFiT: Efficient Multi-lingual Language Model Fine-tuning', 2019)
# 3	0.982	('Unsupervised Word Mapping Using Structural Similarities in Monolingual Embeddings', 2018)
# 3	0.981	('Rotated Word Vector Representations and their Interpretability', 2017)
#
# language nlp natural processing research tasks models tutorial linguistic analysis
#
# 4	0.907	('Visualizing Inferred Morphotactic Systems', 2019)
# 4	0.861	('Tractable Lexical-Functional Grammar', 2020)
# 4	0.837	('How Does NLP Benefit Legal System: A Summary of Legal Artificial Intelligence', 2020)
# 4	0.834	('Texar: A Modularized, Versatile, and Extensible Toolkit for Text Generation', 2019)
# 4	0.831	('The glass ceiling in NLP', 2018)
#
# generation text evaluation models human method topic propose training show
#
# 5	0.946	('COD3S: Diverse Generation with Discrete Semantic Signatures', 2020)
# 5	0.941	('Automatic Evaluation of Local Topic Quality', 2019)
# 5	0.937	('Designing Precise and Robust Dialogue Response Evaluators', 2020)
# 5	0.921	('Paraphrase Generation with Deep Reinforcement Learning', 2018)
# 5	0.919	('A Skeleton-Based Model for Promoting Coherence Among Sentences in Narrative Story Generation', 2018)
#
# knowledge extraction relation relations event models events information task approach
#
# 6	0.980	('Relative and Incomplete Time Expression Anchoring for Clinical Text', 2020)
# 6	0.866	('Evidence-based Trustworthiness', 2019)
# 6	0.830	('Extracting Relations between Radiotherapy Treatment Details', 2020)
# 6	0.784	('Constrained Fact Verification for FEVER', 2020)
# 6	0.740	('Improving Evidence Detection by Leveraging Warrants', 2019)
#
# parsing semantic dependency syntactic parser task features entity system results
#
# 7	0.976	('Initial Explorations of CCG Supertagging for Universal Dependency Parsing', 2017)
# 7	0.972	('Abstract Meaning Representation Parsing using LSTM Recurrent Neural Networks', 2017)
# 7	0.970	('The parse is darc and full of errors: Universal dependency parsing with transition-based and graph-based algorithms', 2017)
# 7	0.969	('A Simple yet Effective Joint Training Method for Cross-Lingual Universal Dependency Parsing', 2018)
# 7	0.958	('Syntax-aware Neural Semantic Role Labeling with Supertags', 2019)
#
# sentiment dialogue learning user task show models dialog propose paper
#
# 8	0.988	('Learning End-to-End Goal-Oriented Dialog with Maximal User Task Success and Minimal Human Agent Use', 2019)
# 8	0.980	('Neural Generation of Dialogue Response Timings', 2020)
# 8	0.980	('Neural Temporal Opinion Modelling for Opinion Prediction on Twitter', 2020)
# 8	0.972	('Learning to execute instructions in a Minecraft dialogue', 2020)
# 8	0.967	('Help, Anna! Visual Navigation with Natural Multimodal Assistance via Retrospective Curiosity-Encouraging Imitation Learning', 2019)
#
# data domain dataset corpus text domains training new annotation task
#
# 9	0.936	('CogNet: A Large-Scale Cognate Database', 2019)
# 9	0.883	('Writing Strategies for Science Communication: Data and Computational Analysis', 2020)
# 9	0.849	('SLATE: A Super-Lightweight Annotation Tool for Experts', 2019)
# 9	0.843	('A Corpus of Non-Native Written English Annotated for Metaphor', 2018)
# 9	0.831	('Suicidal Risk Detection for Military Personnel', 2020)

# %% [markdown]
# **Q1**: Use this basic framework to plot the distribution of a topic over time (between the years 2013-2020).  Specifically, given a document-topic distribution $\theta$ for an entire corpus such that $\theta_d$ is the document-topic distribution for document $d$ and $\theta_{d,i}$ is the probability of topic $i$ in document $d$, the relative frequency of topic $i$ at time $t$ is the sum of $\theta_{d,i}$ for all documents that are published in year $t$, divided by the total number of documents published in year $t$:
#
# $$
# f(t, i) ={ \sum_{d \in D: date(d) = t} \theta_{d,i} \over \sum_{d \in D: date(d) = t} 1}
# $$
#
# For all of the $K$ topics you learn above, plot the distribution of that topic over time (i.e., the x-axis should be time from 2013-2020 and the y-axis should be the relative frequency value $f$ defined above).  Your output here should be $K$ line charts paired with their topic signatures (e.g., from `topic_model.show_topic`, so that we know what topic the chart corresponds to).  See below for sample code generating such a line chart with x, y inputs.

# %%
import matplotlib.pyplot as plt

a=[2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
b=[0.4, 0.3, 0.1, 0.9, 0.04, 0.5, 0.45, 0.3 ]

def plot_category(a,b):
    plt.plot(a,b)
    plt.show()

plot_category(a,b)

# %%
import numpy as np
import pandas as pd
years = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
split = list(zip(*doc_names)) # splitting the corpus for indexing
import matplotlib.pyplot as plt 

def rel_freq(topic_num, year):
    """Topic num: numeric value from 0 to k;
    Year: year of the documents to analyze"""
    
    # Create dataframe to access data
    doc_df = pd.DataFrame.from_dict(
        {"Title": list(split[0]), 
         "Year": list(split[1]), 
         "doc_ID": list(range(len(corpus)))})
    
    # Find all docs from that year
    docs_in_year = doc_df[doc_df["Year"] == year]
    num_docs_in_year = len(docs_in_year) # denominator
    
    topic_probs = np.array([]) # numerator array
    
    for doc_ID in docs_in_year["doc_ID"]:
        
        # Use topic model to pull topics for specific document
        results = topic_model.get_document_topics(corpus[doc_ID])
        
        # Check all present topics and their related probabilities
        for topic, prob in results:
            
            # If topic matches the topic of interest, add it 
            if topic == topic_num:
                topic_probs = np.append(topic_probs, prob)
    
    frac = sum(topic_probs) / num_docs_in_year
    
    return frac

# %%
def plot_all(topic_list, years_list):
    for num in topic_list:
        x = years_list
        y = []
        
        for year in years_list:
            y.append(rel_freq(num, year))
        
        assoc_words = " ".join(list(list(zip(*lda_model.show_topic(num, topn=3)))[0]))
        plt.plot(x, y)
        plt.title("Topic ID:" + str(num) + " and representative words: " + assoc_words)
        plt.show()

# %%
topics = list(range(K))

plot_all(topics, years)
